# %% [markdown]
# # 0. Connect to github classroom
#
# Some of the assignments in this unit will be managed via GitHub classroom. Please follow these steps to connect:
#
# 1. Follow this invitation link and accept the invitation: https://classroom.github.com/a/ALob6RdN
# 2. The link may ask you to sign in to GitHub (if you haven't signed in earlier). If you don't have a GitHub account, you will need to register.
# 3. Once you have logged in with GitHub, you may need to select your email address to associate your GitHub account with your email address (if you haven't done it in a previous COMP3420/COMP6420 activity). If you can't find your email address, please skip this step and contact diego.molla-aliod@mq.edu.au so that he can do the association manually.
# 4. Wait a minute or two, and refresh the browser until it indicates that your assignment repository has been created. Your repository is private to you, and you have administration privileges. Only you and the lecture will have access to it. The repository will be listed under the list of repositories belonging to this offering of COMP3420/COMP6420: https://github.com/orgs/COMP3420-2025S1/repositories
# 5. Your assignment repository will include starter code that you can use for the exercises below. Clone your repository into a folder in your computer.
#
#
# The exercises will have associated automated tests. To run these tests, please commit your changes and push the changes to your repository. This will initiate the automated tests, and you will receive the test results. There are no marks associated with these tests, but they will help you get used to the environment that you will use for the assignments.
#
# **To learn more about the use of github classroom, watch the video named "Github classsroom" in the Echo Active Learning Platform**
#
#
# # 1. Process a greyscale image
#
# Using matplotlib, read the grayscale image stored in file `stickanimalsGray.png` and perform the following tasks:
#
# 1. Write a function `greyscale_rowscolumns(greyscaleimage)` that returns the number of rows and columns of the image.
# 2. Write a function `greyscale_invert(greyscaleimage)` that returns a new image that has the luminosity inverted. That is, all dark pixels should be bright, all bright pixels should be dark. You can do this by converting the pixel value $i$ to $255-i$. Display the resulting image.
# 3. Write a function `greyscale_highest_luminosity(greyscaleimage)` that returns the luminosity of the lightest pixel (hint: use numpy's `max`)
# 4. Write a function `greyscale_blackout(greyscaleimage)` that blacks out all pixels that have an intensity larger than 200. The resulting image should look like this:
# 5. (optional, advanced) Write a function that returns the position of the darkest pixel (hint: use numpy's `argmax`, combined with `unravel_index`; read https://numpy.org/doc/stable/reference/generated/numpy.argmax.html)
#
# Below are examples of usage of the non-advanced exercises:

# %%
from matplotlib import pyplot as plt
import week1
greyimage = plt.imread('stickanimalsGray.png')
plt.imshow(greyimage, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(647.5), np.float64(616.5), np.float64(-0.5))

# %%
week1.greyscale_rowscolumns(greyimage)
# Out:
# (617, 648)

# %%
inverted = week1.greyscale_invert(greyimage)
plt.imshow(inverted, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(647.5), np.float64(616.5), np.float64(-0.5))

# %%
week1.greyscale_highest_luminosity(greyimage)
# Out:
# np.float32(0.99607843)

# %%
blackout = week1.greyscale_blackout(greyimage,0.9)
plt.imshow(blackout, cmap='gray')

# %% [markdown]
# # 2. Process a 3-channel colour image
#
# (these exercises do not have associated tests in github classroom))
#
# Using matplotlib, read the colour image stored in file `stickanimals.jpg` and perform the following tasks:
#
# 1. Write a function `colour_rowscolumns(image)` that determines the number of rows and columns in the image.
# 2. Write a function `remove_red` that has the red channel removed. You can achieve this by setting all values of the red channel to zero.
# 4. Write a function `to_greyscale` that creates a new image that is the greyscale version of the original image. To convert the image to greyscale, each pixel in the new image should be computed as the average of the channel values of the corresponding pixel in the original image.
#
# Below are examples of use of these functions.

# %%
from matplotlib import pyplot as plt
colourimage = plt.imread('stickanimals.jpg')
import week1
plt.imshow(colourimage)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(647.5), np.float64(616.5), np.float64(-0.5))

# %%
week1.colour_rowscolumns(colourimage)
# Out:
# (617, 648)

# %%
nored = week1.remove_red(colourimage)
plt.imshow(nored)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(647.5), np.float64(616.5), np.float64(-0.5))

# %%
greyversion = week1.to_greyscale(colourimage)
plt.imshow(greyversion, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(647.5), np.float64(616.5), np.float64(-0.5))

# %% [markdown]
# # 4. Using a webcam
#
# (this exercise does not have associated tests in github classroom)
#
# Plug in a webcam to your computer and write a function `capture_image` that captures an image from the webcam and saves it into a file. The starter code has a copy of the code from the lecture notebook.
#
# Here is an example of use:

# %%
week1.capture_image('myimage.jpg')
myimage=plt.imread('myimage.jpg')
plt.imshow(myimage)
# Out:
# Initialising video capture
# Capturing frame
# Releasing webcam
# Saving frame to file

# %% [markdown]
# Then, answer the following questions:
#
# 1. What is the resolution of the saved image and how many channels are stored? (hint: load the image and calculate the shape of the resulting NumPy array)
# 2. Are the channels stored in the order Red, Green, Blue, or different? (hint: you can load the image and display it using `plt.imshow`, and observe how the image looks).

# %% [markdown]
# # 5. Post-practical questionnaire
#
# Please complete the week 1 post-practical questionnaire on iLearn.
